# %% [markdown]
# # Week 12: Visualising Geospatial Data with `GeoPandas` - Class Exercises

# %% [markdown]
# We first load the packages necessary for this exercise.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from plotnine import *

# %% [markdown]
# # 1. Singapore Map
#
# Consider the Singapore map we created during class that shows the demographic distribution of the country in 2023.
#
# We will now improve upon the map by annotating the following towns on the same map.
#
# (a) Geo-code the following towns by finding out their latitude and longitude and store all the information in a `GeoDataFrame` named `towns`:
#
# ['ANG MO KIO', 'BEDOK', 'BISHAN', 'CLEMENTI', 'JURONG', 'SENGKANG', 'PUNGGOL', 'TOA PAYOH']
#
# **Hint**\
# Use your favourite LLM to help you with the coordinates.

# %%
# Type your code here:

# %% [markdown]
# (b) Using the `GeoDataFrame` named `towns`, the files `wk12_MasterPlan2019.geojson` and `wk12_sg_pop.csv`, recreate the following Singapore Choropleth Map using `GeoPandas`.
#
# ![image.png](attachment:image.png)

# %%
# Type your code here:

# %% [markdown]
# (c) Now do the same using the `geom_map` function from `plotnine`.
#
# ![image.png](attachment:image.png)
#
# **Hint**\
# Use `geom_text` to label the towns. The (x,y) coordinates can be accessed as `towns.geometry.x` and `towns.geometry.y`.

# %%
# Type your code here:
