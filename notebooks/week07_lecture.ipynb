# %% [markdown]
# # Week 7: Tidy Data / Relational Data - Class Exercises

# %% [markdown]
# We first load the packages necessary for this exercise.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from itables import show

# %% [markdown]
# ---
# ## 1. International Visitor Arrivals in Singapore
#
# In this question, we revisit the tourist data we came across previously.\
# The file `tourist.csv` (available from `Canvas > Files > data`) contains monthly international visitor arrivals by length of stay from July to December in 2023,
# retrieved from the Singapore Department of Statistics. \
# Let’s start by reading in the data as `df`.

# %%
# data for q1
df = pd.read_csv('../data/tourist.csv')
print(df)
# Out:
#        Data Series  2023 Dec  2023 Nov  2023 Oct  2023 Sep  2023 Aug  2023 Jul
# 0      Under 1 Day    259568    240351    236035    227788    248805    269994
# 1            1 Day    189997    181139    175731    166190    190444    202319
# 2           2 Days    162209    177977    181721    167772    197076    205910
# 3           3 Days    168788    168898    189215    172901    210238    216598
# 4           4 Days    117981    105229    126509    114319    162079    160111
# 5           5 Days     64785     56366     69110     62421     98284     98065
# 6           6 Days     38500     31919     37922     37647     52957     58609
# 7           7 Days     25082     21058     24014     25955     32983     37887
# 8        8-10 Days     31446     26251     29618     29818     39565     43611
# 9       11-14 Days     19370     15348     16519     16837     24048     25987
# 10  15 Days & Over     36116     32110     33901     34642     51712     47266
# 11      15-29 Days     25795     22262     23288     23452     35832     35359
# 12      30-59 Days      7191      6749      7300      7601     12256      8826
# 13  60 Days & Over      3130      3099      3313      3589      3624      3081

# %% [markdown]
# (A) Tidy the data and store the result in a data frame named `q1a`. Specifically:
# - Remove the rows for the arrival category "15 Days & Over".
# - Reshape the data into a tidy format.
# - From the `month` column, extract numeric `year` and numeric `month`.
# - Keep only these columns: `year`, `month`, `Data Series`, and `arrivals`.
#
# The first two rows of resulting data frame should look like:
#
# |   |year  | month | Data Series | arrivals |
# |---|------|-------|-------------|----------|
# | 0 | 2023 | 12    | Under 1 Day | 259568   |
# | 1 | 2023 | 12    | 1 Day       | 189997   |

# %%
# Type your code here:

# %% [markdown]
# (B) Calculate the total international arrivals for each month.
# - Store the results in a data frame named `q1b`.
# - Keep only these columns in `q1b`: `month` and `arrivals`.
# - Display all the rows of `q1b`.

# %%
# Type your code here:

# %% [markdown]
# (C) Using `q1b`, calculate the month-on-month rate of change in total tourist arrivals from August to December 2023.
# - Store the results in a new data frame named `q1c`, with the percentage change rate saved in a column named `rate`.
# - Keep only these columns in `q1c`: `month`, `arrivals` and `rate`.
# - Display all the rows of `q1c`.
#
# **Hint**: $\displaystyle \text{rate}_i = \frac{\text{arrival}_i-\text{arrival}_{i-1}}{\text{arrival}_{i-1}} \times 100.$

# %%
# Type your code here:

# %% [markdown]
# (D) Using `q1c`, re-create, as closely as you can, the bar plot below to visualize month-on-month rate of change in total tourist arrivals from August to December 2023.
#
# ![image.png](attachment:image.png)

# %%
# Type your code here:

# %% [markdown]
# ---
# ## 2. Flight Cancellations
# In this question, we will use the `flights` and `airports` tables from the `nycflights13` data set.
#
# The files `flights.csv.zip` and `airports.csv` are available in `Canvas > Files > data > nycflights13`.\
# Let’s start by reading in the two tables and displaying them.

# %%
# data for q2
flights  = pd.read_csv("../data/nycflights13/flights.csv.zip")
airports = pd.read_csv("../data/nycflights13/airports.csv")

show(flights)
show(airports)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c6650740_6197_4590_9b15_59b8c405fcf1"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.7.0 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_c6650740_6197_4590_9b15_59b8c405fcf1:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "classes": ["display", "nowrap", "compact"], "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 336,776 rows as maxBytes=64KB", "filtered_row_count": 336345, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>year</th>\n      <th>month</th>\n      <th>day</th>\n      <th>dep_time</th>\n      <th>sched_dep_time</th>\n      <th>dep_delay</th>\n      <th>arr_time</th>\n      <th>sched_arr_time</th>\n      <th>arr_delay</th>\n      <th>carrier</th>\n      <th>flight</th>\n      <th>tailnum</th>\n      <th>origin</th>\n      <th>dest</th>\n      <th>air_time</th>\n      <th>distance</th>\n      <th>hour</th>\n      <th>minute</th>\n      <th>time_hour</th>\n    </tr>\n  </thead></table>", "data_json": "[[2013, 1, 1, [\"517.0\", 1], 515, [\"2.0\", 18], [\"830.0\", 20], 819, [\"11.0\", 59], \"UA\", 1545, \"N14228\", \"EWR\", \"IAH\", [\"227.0\", 132], 1400, 5, 15, \"2013-01-01T10:00:00Z\"], [2013, 1, 1, [\"533.0\", 2], 529, [\"4.0\", 20], [\"850.0\", 27], 830, [\"20.0\", 67], \"UA\", 1714, \"N24211\", \"LGA\", \"IAH\", [\"227.0\", 132], 1416, 5, 29, \"2013-01-01T10:00:00Z\"], [2013, 1, 1, [\"542.0\", 3], 540, [\"2.0\", 18], [\"923.0\", 44], 850, [\"33.0\", 78], \"AA\", 1141, \"N619AA\", \"JFK\", \"MIA\", [\"160.0\", 106], 1089, 5, 40, \"2013-01-01T10:00:00Z\"], [2013, 1, 1, [\"544.0\", 4], 545, [\"-1.0\", 15], [\"1004.0\", 63], 1022, [\"-18.0\", 30], \"B6\", 725, \"N804JB\", \"JFK\", \"BQN\", [\"183.0\", 121], 1576, 5, 45, \"2013-01-01T10:00:00Z\"], [2013, 1, 1, [\"554.0\", 5], 600, [\"-6.0\", 10], [\"812.0\", 16], 837, [\"-25.0\", 23], \"DL\", 461, \"N668DN\", \"LGA\", \"ATL\", [\"116.0\", 67], 762, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\"554.0\", 5], 558, [\"-4.0\", 12], [\"740.0\", 13], 728, [\"12.0\", 60], \"UA\", 1696, \"N39463\", \"EWR\", \"ORD\", [\"150.0\", 97], 719, 5, 58, \"2013-01-01T10:00:00Z\"], [2013, 1, 1, [\"555.0\", 6], 600, [\"-5.0\", 11], [\"913.0\", 40], 854, [\"19.0\", 66], \"B6\", 507, \"N516JB\", \"EWR\", \"FLL\", [\"158.0\", 104], 1065, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\"557.0\", 7], 600, [\"-3.0\", 13], [\"709.0\", 10], 723, [\"-14.0\", 34], \"EV\", 5708, \"N829AS\", \"LGA\", \"IAD\", [\"53.0\", 21], 229, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\"557.0\", 7], 600, [\"-3.0\", 13], [\"838.0\", 23], 846, [\"-8.0\", 40], \"B6\", 79, \"N593JB\", \"JFK\", \"MCO\", [\"140.0\", 87], 944, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\"558.0\", 8], 600, [\"-2.0\", 14], [\"753.0\", 14], 745, [\"8.0\", 56], \"AA\", 301, \"N3ALAA\", \"LGA\", \"ORD\", [\"138.0\", 85], 733, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\"558.0\", 8], 600, [\"-2.0\", 14], [\"849.0\", 26], 851, [\"-2.0\", 46], \"B6\", 49, \"N793JB\", \"JFK\", \"PBI\", [\"149.0\", 96], 1028, 6, 0, \"2013-01-01T11:00:00Z\"], [2013, 1, 1, [\
675], [\"-88.375111\", 589], 875, -6, \"U\", \"America/Chicago\"], [\"17G\", \"Port Bucyrus-Crawford County Airport\", [\"40.781556\", 559], [\"-82.974806\", 738], 1003, -5, \"A\", \"America/New_York\"], [\"19A\", \"Jackson County Airport\", [\"34.175864\", 265], [\"-83.561597\", 718], 951, -5, \"U\", \"America/New_York\"], [\"1A3\", \"Martin Campbell Field Airport\", [\"35.015806\", 312], [\"-84.346833\", 694], 1789, -5, \"A\", \"America/New_York\"], [\"1B9\", \"Mansfield Municipal\", [\"42.000133\", 649], [\"-71.196771\", 997], 122, -5, \"A\", \"America/New_York\"], [\"1C9\", \"Frazier Lake Airpark\", [\"54.013333\", 869], [\"-124.768333\", 162], 152, -8, \"A\", \"America/Vancouver\"], [\"1CS\", \"Clow International Airport\", [\"41.695974\", 625], [\"-88.129231\", 596], 670, -6, \"U\", \"America/Chicago\"], [\"1G3\", \"Kent State Airport\", [\"41.151389\", 582], [\"-81.415111\", 797], 1134, -5, \"A\", \"America/New_York\"], [\"1G4\", \"Grand Canyon West Airport\", [\"35.899904\", 341], [\"-113.815674\", 306], 4813, -7, \"A\", \"America/Phoenix\"], [\"1H2\", \"Effingham Memorial Airport\", [\"39.070000\", 461], [\"-88.534000\", 582], 585, -6, \"A\", \"America/Chicago\"], [\"1OH\", \"Fortman Airport\", [\"40.555325\", 545], [\"-84.386619\", 692], 885, -5, \"U\", \"America/New_York\"], [\"1RL\", \"Point Roberts Airpark\", [\"48.979722\", 864], [\"-123.078889\", 176], 10, -8, \"A\", \"America/Los_Angeles\"], [\"23M\", \"Clarke CO\", [\"32.051700\", 148], [\"-88.443400\", 587], 320, -6, \"A\", \"America/Chicago\"], [\"24C\", \"Lowell City Airport\", [\"42.953920\", 707], [\"-85.343906\", 655], 681, -5, \"A\", \"America/New_York\"], [\"24J\", \"Suwannee County Airport\", [\"30.300125\", 95], [\"-83.024694\", 736], 104, -5, \"A\", \"America/New_York\"], [\"25D\", \"Forest Lake Airport\", [\" ...

# %% [markdown]
# (A) Filter the `flights` table to keep only flights operated by United Airlines (UA).
# - Define a flight to be cancelled if the departure time is missing.
# - For each `origin` and `month`, compute the cancellation rate.
# - Store the result in a tidy data frame named `q2a`.
#
# The first two rows of `q2a` should look like this:
#
# |   | origin | month | total | cancelled | rate     |
# |---|--------|-------|-------|-----------|----------|
# | 0 | EWR    | 1     | 3657  | 21        | 0.574241 |
# | 1 | EWR    | 2     | 3433  | 131       | 3.815904 |

# %%
# Type your code here:

# %% [markdown]
# (B) Join `q2a` with the `airports` table to add the corresponding airport names for each origin airport code.
# - Next, pivot the table to wide format so that each airport has its own column listing it's cancellation rates for each month.
# - The resulting data frame `q2b` should look like this.
#
# |   | month	| John F Kennedy Intl | La Guardia | Newark Liberty Intl |
# |---|-------|---------------------|------------|---------------------|
# | 0	| Jan	| 0.263158	          | 1.666667   | 0.574241            |
# | 1	| Feb	| 4.651163	          | 5.799649   | 3.815904            |
#
# - Using `q2b`, re-create, as closely as you can, the following time series line plot to visualize the flight cancellation rates across months for each origin airport.
#
# ![image.png](attachment:image.png)

# %%
# Type your code here:
